# %% [markdown]
# # Import des librairies et conneexion à la base de données

# %%
from sqlalchemy import create_engine
import pandas as pd
from dotenv import load_dotenv
import os

load_dotenv()
database_url = os.getenv("DATABASE_URL") # url de la base de données stocké dans un fichier .env sous la variable DATABASE_URL
engine = create_engine(database_url)
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In[1], line 8
#       6 load_dotenv()
#       7 database_url = os.getenv("DATABASE_URL") # url de la base de données stocké dans un fichier .env sous la variable DATABASE_URL
# ----> 8 engine = create_engine(database_url)
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File c:\Users\p2972\OneDrive\Greta\Projets\Netfloox\venv\Lib\site-packages\sqlalchemy\util\deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File c:\Users\p2972\OneDrive\Greta\Projets\Netfloox\venv\Lib\site-packages\sqlalchemy\engine\create.py:549, in create_engine(url, **kwargs)
#     546 kwargs.pop("empty_in_strategy", None)
#     548 # create url.URL object
# --> 549 u = _url.make_url(url)
#     551 u, plugins, kwargs = u._instantiate_plugins(kwargs)
#     553 entrypoint = u._get_entrypoint()
#
# File c:\Users\p2972\OneDrive\Greta\Projets\Netfloox\venv\Lib\site-packages\sqlalchemy\engine\url.py:860, in make_url(name_or_url)
#     856     return _parse_url(name_or_url)
#     857 elif not isinstance(name_or_url, URL) and not hasattr(
#     858     name_or_url, "_sqla_is_testing_if_this_is_a_mock_object"
#     859 ):
# --> 860     raise exc.ArgumentError(
#     861         f"Expected string or URL object, got {name_or_url!r}"
#     862     )
#     863 else:
#     864     return name_or_url
#
# ArgumentError: Expected string or URL object, got None

# %% [markdown]
# # Récupération de la première table

# %%
query = "SELECT tconst, titletype, primarytitle, isadult, startyear, endyear, runtimeminutes, genres, averagerating, numvotes FROM sebastien.title_basics ORDER BY tconst LIMIT 10000;"
with engine.connect() as conn, conn.begin():
    df = pd.read_sql_query(query, engine)

df.head()
# Out:
#        tconst  titletype        primarytitle  isadult  startyear  endyear  \
# 0  tt12605172  tvEpisode        Episode #1.2    False     2020.0      NaN
# 1  tt12605176  tvSpecial   Shaheb Bibi Golam    False     2016.0      NaN
# 2  tt12605178      short  Girl in the Mirror    False     2020.0      NaN
# 3   tt1260518  tvEpisode          Loose Ends    False     2008.0      NaN
# 4  tt12605180  tvEpisode        Episode #1.3    False     2020.0      NaN
#
#    runtimeminutes          genres  averagerating  numvotes
# 0             NaN  Action,Mystery            NaN       NaN
# 1             NaN           Drama            NaN       NaN
# 2             6.0     Music,Short            NaN       NaN
# 3             NaN           Drama            NaN       NaN
# 4             NaN  Action,Mystery            NaN       NaN

# %% [markdown]
# On récupère seulement les 10000 premières lignes ordonnées par tconst pour pouvoir par la suite récupérer les données des autres tables selon ces 10000 lignes.

# %% [markdown]
# # Récupération de la table episode et join

# %% [markdown]
# ### Récupération de la table dans la base de données

# %%
query = "SELECT * FROM sebastien.title_episode;"
with engine.connect() as conn, conn.begin():
    df_episode = pd.read_sql_query(query, engine)

df_episode.head()
# Out:
#        tconst parenttconst  seasonnumber  episodenumber
# 0  tt12155488   tt12145510           1.0            7.0
# 1   tt1215549    tt0990536           1.0            3.0
# 2  tt12155490   tt12092480           1.0          211.0
# 3  tt12155492   tt12092480           1.0          212.0
# 4  tt12155494   tt12145510           1.0            8.0

# %% [markdown]
# La complication est que certaines lignes de title_basics sont liés à title_episode par la colonne tconst de title_episode tandis que d'autres sont liés par la colonne parentTconst.

# %% [markdown]
# ### Premier merge avec tconst

# %%
df_merge = df.merge(df_episode, on="tconst", how="left")
df_merge
# Out:
#           tconst  titletype                        primarytitle  isadult  \
# 0     tt12605172  tvEpisode                        Episode #1.2    False
# 1     tt12605176  tvSpecial                   Shaheb Bibi Golam    False
# 2     tt12605178      short                  Girl in the Mirror    False
# 3      tt1260518  tvEpisode                          Loose Ends    False
# 4     tt12605180  tvEpisode                        Episode #1.3    False
# ...          ...        ...                                 ...      ...
# 9995  tt12624184  tvEpisode                     Canción de cuna    False
# 9996  tt12624186  videoGame  Go Diego Go! Great Dinosaur Rescue    False
# 9997   tt1262419      movie               Sanpei the Fisher Boy    False
# 9998  tt12624194      movie                       Debbie's Time     True
# 9999  tt12624196  tvEpisode                         Desperation    False
#
#       startyear  endyear  runtimeminutes                genres  averagerating  \
# 0        2020.0      NaN             NaN        Action,Mystery            NaN
# 1        2016.0      NaN             NaN                 Drama            NaN
# 2        2020.0      NaN             6.0           Music,Short            NaN
# 3        2008.0      NaN             NaN                 Drama            NaN
# 4        2020.0      NaN             NaN        Action,Mystery            NaN
# ...         ...      ...             ...                   ...            ...
# 9995     2001.0      NaN             NaN  Crime,Drama,Thriller            NaN
# 9996     2008.0      NaN             NaN             Adventure            5.3
# 9997     2009.0      NaN           118.0                 Drama            6.1
# 9998     1971.0      NaN             NaN                 Adult            NaN
# 9999     2020.0      NaN            17.0                Sci-Fi            NaN
#
#       numvotes parenttconst  seasonnumber  episodenumber
# 0          NaN   tt12465816           1.0            2.0
# 1          NaN          NaN           NaN            NaN
# 2          NaN          NaN           NaN            NaN
# 3          NaN    tt0210405          18.0            5.0
# 4          NaN   tt12465816           1.0            3.0
# ...        ...          ...           ...            ...
# 9995       NaN    tt0222600           NaN            NaN
# 9996       7.0          NaN           NaN            NaN
# 9997     109.0          NaN           NaN            NaN
# 9998       NaN          NaN           NaN            NaN
# 9999       NaN    tt7275066           1.0            4.0
#
# [10000 rows x 13 columns]

# %% [markdown]
# ### Deuxième merge par parenttconst

# %%
df_merge_parent = df.merge(df_episode, left_on="tconst", right_on="parenttconst", how="left", suffixes=('', '_parent'))
df_merge_parent
# Out:
#            tconst  titletype                        primarytitle  isadult  \
# 0      tt12605172  tvEpisode                        Episode #1.2    False
# 1      tt12605176  tvSpecial                   Shaheb Bibi Golam    False
# 2      tt12605178      short                  Girl in the Mirror    False
# 3       tt1260518  tvEpisode                          Loose Ends    False
# 4      tt12605180  tvEpisode                        Episode #1.3    False
# ...           ...        ...                                 ...      ...
# 21704  tt12624184  tvEpisode                     Canción de cuna    False
# 21705  tt12624186  videoGame  Go Diego Go! Great Dinosaur Rescue    False
# 21706   tt1262419      movie               Sanpei the Fisher Boy    False
# 21707  tt12624194      movie                       Debbie's Time     True
# 21708  tt12624196  tvEpisode                         Desperation    False
#
#        startyear  endyear  runtimeminutes                genres  \
# 0         2020.0      NaN             NaN        Action,Mystery
# 1         2016.0      NaN             NaN                 Drama
# 2         2020.0      NaN             6.0           Music,Short
# 3         2008.0      NaN             NaN                 Drama
# 4         2020.0      NaN             NaN        Action,Mystery
# ...          ...      ...             ...                   ...
# 21704     2001.0      NaN             NaN  Crime,Drama,Thriller
# 21705     2008.0      NaN             NaN             Adventure
# 21706     2009.0      NaN           118.0                 Drama
# 21707     1971.0      NaN             NaN                 Adult
# 21708     2020.0      NaN            17.0                Sci-Fi
#
#        averagerating  numvotes tconst_parent parenttconst  seasonnumber  \
# 0                NaN       NaN           NaN          NaN           NaN
# 1                NaN       NaN           NaN          NaN           NaN
# 2                NaN       NaN           NaN          NaN           NaN
# 3                NaN       NaN           NaN          NaN           NaN
# 4                NaN       NaN           NaN          NaN           NaN
# ...              ...       ...           ...          ...           ...
# 21704            NaN       NaN           NaN          NaN           NaN
# 21705            5.3       7.0           NaN          NaN           NaN
# 21706            6.1     109.0           NaN          NaN           NaN
# 21707            NaN       NaN           NaN          NaN           NaN
# 21708            NaN       NaN           NaN          NaN           NaN
#
#        episodenumber
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 21704            NaN
# 21705            NaN
# 21706            NaN
# 21707            NaN
# 21708            NaN
#
# [21709 rows x 14 columns]

# %% [markdown]
# ### On combine les deux merge

# %%
df = pd.concat([df_merge, df_merge_parent], ignore_index=True)
df
# Out:
#            tconst  titletype                        primarytitle  isadult  \
# 0      tt12605172  tvEpisode                        Episode #1.2    False
# 1      tt12605176  tvSpecial                   Shaheb Bibi Golam    False
# 2      tt12605178      short                  Girl in the Mirror    False
# 3       tt1260518  tvEpisode                          Loose Ends    False
# 4      tt12605180  tvEpisode                        Episode #1.3    False
# ...           ...        ...                                 ...      ...
# 31704  tt12624184  tvEpisode                     Canción de cuna    False
# 31705  tt12624186  videoGame  Go Diego Go! Great Dinosaur Rescue    False
# 31706   tt1262419      movie               Sanpei the Fisher Boy    False
# 31707  tt12624194      movie                       Debbie's Time     True
# 31708  tt12624196  tvEpisode                         Desperation    False
#
#        startyear  endyear  runtimeminutes                genres  \
# 0         2020.0      NaN             NaN        Action,Mystery
# 1         2016.0      NaN             NaN                 Drama
# 2         2020.0      NaN             6.0           Music,Short
# 3         2008.0      NaN             NaN                 Drama
# 4         2020.0      NaN             NaN        Action,Mystery
# ...          ...      ...             ...                   ...
# 31704     2001.0      NaN             NaN  Crime,Drama,Thriller
# 31705     2008.0      NaN             NaN             Adventure
# 31706     2009.0      NaN           118.0                 Drama
# 31707     1971.0      NaN             NaN                 Adult
# 31708     2020.0      NaN            17.0                Sci-Fi
#
#        averagerating  numvotes parenttconst  seasonnumber  episodenumber  \
# 0                NaN       NaN   tt12465816           1.0            2.0
# 1                NaN       NaN          NaN           NaN            NaN
# 2                NaN       NaN          NaN           NaN            NaN
# 3                NaN       NaN    tt0210405          18.0            5.0
# 4                NaN       NaN   tt12465816           1.0            3.0
# ...              ...       ...          ...           ...            ...
# 31704            NaN       NaN          NaN           NaN            NaN
# 31705            5.3       7.0          NaN           NaN            NaN
# 31706            6.1     109.0          NaN           NaN            NaN
# 31707            NaN       NaN          NaN           NaN            NaN
# 31708            NaN       NaN          NaN           NaN            NaN
#
#       tconst_parent
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 31704           NaN
# 31705           NaN
# 31706           NaN
# 31707           NaN
# 31708           NaN
#
# [31709 rows x 14 columns]

# %%
df[df["tconst"].duplicated()]
# Out:
#            tconst  titletype                        primarytitle  isadult  \
# 10000  tt12605172  tvEpisode                        Episode #1.2    False
# 10001  tt12605176  tvSpecial                   Shaheb Bibi Golam    False
# 10002  tt12605178      short                  Girl in the Mirror    False
# 10003   tt1260518  tvEpisode                          Loose Ends    False
# 10004  tt12605180  tvEpisode                        Episode #1.3    False
# ...           ...        ...                                 ...      ...
# 31704  tt12624184  tvEpisode                     Canción de cuna    False
# 31705  tt12624186  videoGame  Go Diego Go! Great Dinosaur Rescue    False
# 31706   tt1262419      movie               Sanpei the Fisher Boy    False
# 31707  tt12624194      movie                       Debbie's Time     True
# 31708  tt12624196  tvEpisode                         Desperation    False
#
#        startyear  endyear  runtimeminutes                genres  \
# 10000     2020.0      NaN             NaN        Action,Mystery
# 10001     2016.0      NaN             NaN                 Drama
# 10002     2020.0      NaN             6.0           Music,Short
# 10003     2008.0      NaN             NaN                 Drama
# 10004     2020.0      NaN             NaN        Action,Mystery
# ...          ...      ...             ...                   ...
# 31704     2001.0      NaN             NaN  Crime,Drama,Thriller
# 31705     2008.0      NaN             NaN             Adventure
# 31706     2009.0      NaN           118.0                 Drama
# 31707     1971.0      NaN             NaN                 Adult
# 31708     2020.0      NaN            17.0                Sci-Fi
#
#        averagerating  numvotes parenttconst  seasonnumber  episodenumber  \
# 10000            NaN       NaN          NaN           NaN            NaN
# 10001            NaN       NaN          NaN           NaN            NaN
# 10002            NaN       NaN          NaN           NaN            NaN
# 10003            NaN       NaN          NaN           NaN            NaN
# 10004            NaN       NaN          NaN           NaN            NaN
# ...              ...       ...          ...           ...            ...
# 31704            NaN       NaN          NaN           NaN            NaN
# 31705            5.3       7.0          NaN           NaN            NaN
# 31706            6.1     109.0          NaN           NaN            NaN
# 31707            NaN       NaN          NaN           NaN            NaN
# 31708            NaN       NaN          NaN           NaN            NaN
#
#       tconst_parent
# 10000           NaN
# 10001           NaN
# 10002           NaN
# 10003           NaN
# 10004           NaN
# ...             ...
# 31704           NaN
# 31705           NaN
# 31706           NaN
# 31707           NaN
# 31708           NaN
#
# [21709 rows x 14 columns]

# %%
df[df["tconst"] == "tt3240414"]
# Out:
# Empty DataFrame
# Columns: [tconst, titletype, primarytitle, isadult, startyear, endyear, runtimeminutes, genres, averagerating, numvotes, parenttconst, seasonnumber, episodenumber, tconst_parent]
# Index: []

# %% [markdown]
# On voit qu'il y a des doublons, il faut donc regrouper les lignes doublons

# %% [markdown]
# Pour cela on peux regrouper les lignes qui ont le même tconst. Pour les colonnes de title_basics, comme la valeur est la même selon les deux merge, on peux garder toujours le premier. Pour les colonnes de title_episode, pour éliminer les lignes où la valeur est vide, on peux garder la valeur max, qui est donc celle non nulle.

# %%
df = df.groupby('tconst').agg({
    'titletype': 'first', # on garde  le titletype de la première ligne
    'primarytitle': 'first',
    'isadult': 'first',
    'startyear': 'first',
    'endyear': 'first',
    'runtimeminutes': 'first',
    'genres': 'first',
    'averagerating': 'first',
    'numvotes': 'first',
    'seasonnumber': 'max', # on garde le max de seasonnumber, soit le non nul
    'episodenumber': 'max'
}).reset_index()
df
# Out:
#           tconst  titletype                        primarytitle  isadult  \
# 0     tt12605172  tvEpisode                        Episode #1.2    False
# 1     tt12605176  tvSpecial                   Shaheb Bibi Golam    False
# 2     tt12605178      short                  Girl in the Mirror    False
# 3      tt1260518  tvEpisode                          Loose Ends    False
# 4     tt12605180  tvEpisode                        Episode #1.3    False
# ...          ...        ...                                 ...      ...
# 9995  tt12624184  tvEpisode                     Canción de cuna    False
# 9996  tt12624186  videoGame  Go Diego Go! Great Dinosaur Rescue    False
# 9997   tt1262419      movie               Sanpei the Fisher Boy    False
# 9998  tt12624194      movie                       Debbie's Time     True
# 9999  tt12624196  tvEpisode                         Desperation    False
#
#       startyear  endyear  runtimeminutes                genres  averagerating  \
# 0        2020.0      NaN             NaN        Action,Mystery            NaN
# 1        2016.0      NaN             NaN                 Drama            NaN
# 2        2020.0      NaN             6.0           Music,Short            NaN
# 3        2008.0      NaN             NaN                 Drama            NaN
# 4        2020.0      NaN             NaN        Action,Mystery            NaN
# ...         ...      ...             ...                   ...            ...
# 9995     2001.0      NaN             NaN  Crime,Drama,Thriller            NaN
# 9996     2008.0      NaN             NaN             Adventure            5.3
# 9997     2009.0      NaN           118.0                 Drama            6.1
# 9998     1971.0      NaN             NaN                 Adult            NaN
# 9999     2020.0      NaN            17.0                Sci-Fi            NaN
#
#       numvotes  seasonnumber  episodenumber
# 0          NaN           1.0            2.0
# 1          NaN           NaN            NaN
# 2          NaN           NaN            NaN
# 3          NaN          18.0            5.0
# 4          NaN           1.0            3.0
# ...        ...           ...            ...
# 9995       NaN           NaN            NaN
# 9996       7.0           NaN            NaN
# 9997     109.0           NaN            NaN
# 9998       NaN           NaN            NaN
# 9999       NaN           1.0            4.0
#
# [10000 rows x 12 columns]

# %% [markdown]
# # Récupération de la table title_akas et join

# %% [markdown]
# On groupe par tconst pour récupérer pour chaque film directement le nombre de région et la liste des régions, pour prendre le moins de place possible en mémoire.

# %%
query_title_akas = """
SELECT 
    ta.tconst, 
    COUNT(DISTINCT ta.region) AS regionnumber, 
    ARRAY_AGG(ta.region) AS regionlist
FROM 
    sebastien.title_akas ta
WHERE 
    ta.tconst IN (SELECT tconst FROM sebastien.title_basics ORDER BY tconst LIMIT 10000)
GROUP BY 
    ta.tconst;
"""

with engine.connect() as conn, conn.begin():
    df_akas = pd.read_sql_query(query_title_akas, conn)

df_akas.head()
# Out:
#        tconst  regionnumber                        regionlist
# 0  tt12605172             8  [PT, IN, FR, IT, DE, JP, \N, ES]
# 1  tt12605176             2                          [\N, BD]
# 2  tt12605178             2                          [\N, US]
# 3   tt1260518             1                              [\N]
# 4  tt12605180             8  [\N, PT, IN, FR, IT, DE, JP, ES]

# %%
def replace_and_filter(region_list):
    if isinstance(region_list, list):
        return [region for region in region_list if region != '\\N' and region != '']
    return region_list
df_akas['regionlist'] = df_akas['regionlist'].apply(replace_and_filter)
df_akas
# Out:
#           tconst  regionnumber                    regionlist
# 0     tt12605172             8  [PT, IN, FR, IT, DE, JP, ES]
# 1     tt12605176             2                          [BD]
# 2     tt12605178             2                          [US]
# 3      tt1260518             1                            []
# 4     tt12605180             8  [PT, IN, FR, IT, DE, JP, ES]
# ...          ...           ...                           ...
# 9995  tt12624184             2                          [MX]
# 9996  tt12624186             2                          [US]
# 9997   tt1262419             5             [XWW, BR, JP, CN]
# 9998  tt12624194             2                          [US]
# 9999  tt12624196             1                            []
#
# [10000 rows x 3 columns]

# %%
df = df.merge(df_akas, on="tconst", how="left")
df
# Out:
#           tconst  titletype                        primarytitle  isadult  \
# 0     tt12605172  tvEpisode                        Episode #1.2    False
# 1     tt12605176  tvSpecial                   Shaheb Bibi Golam    False
# 2     tt12605178      short                  Girl in the Mirror    False
# 3      tt1260518  tvEpisode                          Loose Ends    False
# 4     tt12605180  tvEpisode                        Episode #1.3    False
# ...          ...        ...                                 ...      ...
# 9995  tt12624184  tvEpisode                     Canción de cuna    False
# 9996  tt12624186  videoGame  Go Diego Go! Great Dinosaur Rescue    False
# 9997   tt1262419      movie               Sanpei the Fisher Boy    False
# 9998  tt12624194      movie                       Debbie's Time     True
# 9999  tt12624196  tvEpisode                         Desperation    False
#
#       startyear  endyear  runtimeminutes                genres  averagerating  \
# 0        2020.0      NaN             NaN        Action,Mystery            NaN
# 1        2016.0      NaN             NaN                 Drama            NaN
# 2        2020.0      NaN             6.0           Music,Short            NaN
# 3        2008.0      NaN             NaN                 Drama            NaN
# 4        2020.0      NaN             NaN        Action,Mystery            NaN
# ...         ...      ...             ...                   ...            ...
# 9995     2001.0      NaN             NaN  Crime,Drama,Thriller            NaN
# 9996     2008.0      NaN             NaN             Adventure            5.3
# 9997     2009.0      NaN           118.0                 Drama            6.1
# 9998     1971.0      NaN             NaN                 Adult            NaN
# 9999     2020.0      NaN            17.0                Sci-Fi            NaN
#
#       numvotes  seasonnumber  episodenumber  regionnumber  \
# 0          NaN           1.0            2.0             8
# 1          NaN           NaN            NaN             2
# 2          NaN           NaN            NaN             2
# 3          NaN          18.0            5.0             1
# 4          NaN           1.0            3.0             8
# ...        ...           ...            ...           ...
# 9995       NaN           NaN            NaN             2
# 9996       7.0           NaN            NaN             2
# 9997     109.0           NaN            NaN             5
# 9998       NaN           NaN            NaN             2
# 9999       NaN           1.0            4.0             1
#
#                             regionlist
# 0     [PT, IN, FR, IT, DE, JP, \N, ES]
# 1                             [\N, BD]
# 2                             [\N, US]
# 3                                 [\N]
# 4     [\N, PT, IN, FR, IT, DE, JP, ES]
# ...                                ...
# 9995                          [\N, MX]
# 9996                          [\N, US]
# 9997             [\N, XWW, BR, JP, CN]
# 9998                          [\N, US]
# 9999                              [\N]
#
# [10000 rows x 14 columns]

# %%
df["regionlist"] = df["regionlist"].str.replace("\\N", "")
df
# Out:
#           tconst  titletype                        primarytitle  isadult  \
# 0     tt12605172  tvEpisode                        Episode #1.2    False
# 1     tt12605176  tvSpecial                   Shaheb Bibi Golam    False
# 2     tt12605178      short                  Girl in the Mirror    False
# 3      tt1260518  tvEpisode                          Loose Ends    False
# 4     tt12605180  tvEpisode                        Episode #1.3    False
# ...          ...        ...                                 ...      ...
# 9995  tt12624184  tvEpisode                     Canción de cuna    False
# 9996  tt12624186  videoGame  Go Diego Go! Great Dinosaur Rescue    False
# 9997   tt1262419      movie               Sanpei the Fisher Boy    False
# 9998  tt12624194      movie                       Debbie's Time     True
# 9999  tt12624196  tvEpisode                         Desperation    False
#
#       startyear  endyear  runtimeminutes                genres  averagerating  \
# 0        2020.0      NaN             NaN        Action,Mystery            NaN
# 1        2016.0      NaN             NaN                 Drama            NaN
# 2        2020.0      NaN             6.0           Music,Short            NaN
# 3        2008.0      NaN             NaN                 Drama            NaN
# 4        2020.0      NaN             NaN        Action,Mystery            NaN
# ...         ...      ...             ...                   ...            ...
# 9995     2001.0      NaN             NaN  Crime,Drama,Thriller            NaN
# 9996     2008.0      NaN             NaN             Adventure            5.3
# 9997     2009.0      NaN           118.0                 Drama            6.1
# 9998     1971.0      NaN             NaN                 Adult            NaN
# 9999     2020.0      NaN            17.0                Sci-Fi            NaN
#
#       numvotes  seasonnumber  episodenumber  regionnumber  regionlist
# 0          NaN           1.0            2.0             8         NaN
# 1          NaN           NaN            NaN             2         NaN
# 2          NaN           NaN            NaN             2         NaN
# 3          NaN          18.0            5.0             1         NaN
# 4          NaN           1.0            3.0             8         NaN
# ...        ...           ...            ...           ...         ...
# 9995       NaN           NaN            NaN             2         NaN
# 9996       7.0           NaN            NaN             2         NaN
# 9997     109.0           NaN            NaN             5         NaN
# 9998       NaN           NaN            NaN             2         NaN
# 9999       NaN           1.0            4.0             1         NaN
#
# [10000 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['tconst', 'titletype', 'primarytitle', 'isadult', 'startyear',
#        'endyear', 'runtimeminutes', 'genres', 'averagerating', 'numvotes',
#        'seasonnumber', 'episodenumber', 'regionnumber', 'regionlist'],
#       dtype='object')

# %% [markdown]
# # Récupération de la table title_principals et name_basics et join

# %% [markdown]
# On récupère les lignes correspondantes aux 10000 premières lignes de title_basics.

# %%
from pandas.core.frame import DataFrame


query_title_akas = """
SELECT 
    tconst,
    category,
    primaryname
FROM 
    sebastien.title_principals ta
JOIN 
    sebastien.name_basics nb 
ON 
    ta.nconst = nb.nconst
WHERE 
    ta.tconst IN (SELECT tconst FROM sebastien.title_basics ORDER BY tconst LIMIT 10000);
"""

with engine.connect() as conn, conn.begin():
    df_principals: DataFrame = pd.read_sql_query(query_title_akas, conn)

df_principals.head()
# Out:
#        tconst  category      primaryname
# 0  tt12605302     actor         Sam Page
# 1  tt12605302    writer  Celeste Vasquez
# 2  tt12605304    writer  Celeste Vasquez
# 3  tt12605530  producer       Jenna Gien
# 4  tt12605626     actor  Wilson Gonzalez

# %% [markdown]
# On groupe les lignes par tconst et category, puis on agrège les primaryname sous forme de liste, et on transforme les category en des colonnes pour chaque category (en remplissant les nulls par des listes vides).

# %%
df_principals = df_principals.groupby(['tconst', 'category'])['primaryname'].agg(list).unstack(fill_value=[]).reset_index()

df_principals = df_principals[["tconst", "actor", "self", "producer", "actress", "director"]]

df_final = pd.merge(df, df_principals, on='tconst', how='left')

df_final.head()
# Out:
#        tconst  titletype        primarytitle  isadult  startyear  endyear  \
# 0  tt12605172  tvEpisode        Episode #1.2    False     2020.0      NaN
# 1  tt12605176  tvSpecial   Shaheb Bibi Golam    False     2016.0      NaN
# 2  tt12605178      short  Girl in the Mirror    False     2020.0      NaN
# 3   tt1260518  tvEpisode          Loose Ends    False     2008.0      NaN
# 4  tt12605180  tvEpisode        Episode #1.3    False     2020.0      NaN
#
#    runtimeminutes          genres  averagerating  numvotes  seasonnumber  \
# 0             NaN  Action,Mystery            NaN       NaN           1.0
# 1             NaN           Drama            NaN       NaN           NaN
# 2             6.0     Music,Short            NaN       NaN           NaN
# 3             NaN           Drama            NaN       NaN          18.0
# 4             NaN  Action,Mystery            NaN       NaN           1.0
#
#    episodenumber  regionnumber  regionlist  \
# 0            2.0             8         NaN
# 1            NaN             2         NaN
# 2            NaN             2         NaN
# 3            5.0             1         NaN
# 4            3.0             8         NaN
#
#                                                actor self  \
# 0  [Ryoma Takeuchi, Kôtarô Yoshida, Hayato Ichiha...   []
# 1                         [Omer Ayaz Ony, Fs Nayeem]   []
# 2                                                 []   []
# 3  [Paul Akl, Michael Apgar, Alex De Leon, Chris ...   []
# 4  [Ryoma Takeuchi, Kôtarô Yoshida, Tatsuya Fujiw...   []
#
#                  producer                                       actress  \
# 0                      []                                 [Mikako Tabe]
# 1  [Hasan Al Mamun Ponir]                                [Aparna Ghosh]
# 2         [Greg L. Hines]                               [Vernae Taylor]
# 3                      []  [Amanda Garant, Angelica Allen, Leah Garvin]
# 4                      []                                 [Mikako Tabe]
#
#                       director
# 0            [Eiichirô Hasumi]
# 1     [Mir Asaduzzaman Ariyan]
# 2              [Greg L. Hines]
# 3  [Tessa Olson, Jenn Carroll]
# 4            [Eiichirô Hasumi]

# %% [markdown]
# # Sauvegarde de notre dataset final

# %%
df.to_csv("data/all_data_for_10000_lines.csv", index=False)

# %% [markdown]
# # Test de la fonction

# %%
import pandas as pd
import sys
sys.path.append('..')
from scripts.FeaturesExtraction import get_extracted_features

# %%
df = get_extracted_features(10000)
df
# Out:
# table 1 / 4
# table 2 / 4
# table 3 / 4
# table 4 / 4
#           tconst  titletype                        primarytitle  isadult  \
# 0     tt12605172  tvEpisode                        Episode #1.2    False
# 1     tt12605176  tvSpecial                   Shaheb Bibi Golam    False
# 2     tt12605178      short                  Girl in the Mirror    False
# 3      tt1260518  tvEpisode                          Loose Ends    False
# 4     tt12605180  tvEpisode                        Episode #1.3    False
# ...          ...        ...                                 ...      ...
# 9995  tt12624184  tvEpisode                     Canción de cuna    False
# 9996  tt12624186  videoGame  Go Diego Go! Great Dinosaur Rescue    False
# 9997   tt1262419      movie               Sanpei the Fisher Boy    False
# 9998  tt12624194      movie                       Debbie's Time     True
# 9999  tt12624196  tvEpisode                         Desperation    False
#
#       startyear                genres  averagerating  numvotes  seasonnumber  \
# 0        2020.0        Action,Mystery            NaN       NaN           1.0
# 1        2016.0                 Drama            NaN       NaN           NaN
# 2        2020.0           Music,Short            NaN       NaN           NaN
# 3        2008.0                 Drama            NaN       NaN          18.0
# 4        2020.0        Action,Mystery            NaN       NaN           1.0
# ...         ...                   ...            ...       ...           ...
# 9995     2001.0  Crime,Drama,Thriller            NaN       NaN           NaN
# 9996     2008.0             Adventure            5.3       7.0           NaN
# 9997     2009.0                 Drama            6.1     109.0           NaN
# 9998     1971.0                 Adult            NaN       NaN           NaN
# 9999     2020.0                Sci-Fi            NaN       NaN           1.0
#
#       episodenumber  regionnumber                        regionlist  \
# 0               2.0             8  [PT, IN, FR, IT, DE, JP, \N, ES]
# 1               NaN             2                          [\N, BD]
# 2               NaN             2                          [\N, US]
# 3               5.0             1                              [\N]
# 4               3.0             8  [\N, PT, IN, FR, IT, DE, JP, ES]
# ...             ...           ...                               ...
# 9995            NaN             2                          [\N, MX]
# 9996            NaN             2                          [\N, US]
# 9997            NaN             5             [\N, XWW, BR, JP, CN]
# 9998            NaN             2                          [\N, US]
# 9999            4.0             1                              [\N]
#
#                                                   actor self  \
# 0     [Ryoma Takeuchi, Kôtarô Yoshida, Hayato Ichiha...   []
# 1                            [Omer Ayaz Ony, Fs Nayeem]   []
# 2                                                    []   []
# 3     [Paul Akl, Michael Apgar, Alex De Leon, Chris ...   []
# 4     [Ryoma Takeuchi, Kôtarô Yoshida, Tatsuya Fujiw...   []
# ...                                                 ...  ...
# 9995         [Roberto Sen, Sebastián Rulli, Hugo Denis]   []
# 9996  [Keeler Sandhaus, Keeler Sandhaus, Keeler Sand...   []
# 9997  [Kenta Suga, Masato Hagiwara, Ryûji Katagiri, ...   []
# 9998                                                 []   []
# 9999  [Patrick Nalty, Colton Dennis, Joseph T. Hypes...   []
#
#                                                producer  \
# 0                                                    []
# 1                                [Hasan Al Mamun Ponir]
# 2                                       [Greg L. Hines]
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 9995                                                 []
# 9996                                                 []
# 9997                                   [Masatake Kondô]
# 9998                                      [Sven Peters]
# 9999  [Brett J. Fox, Joseph Brown, Chad Phillips, Ar...
#
#                                                 actress  \
# 0                                         [Mikako Tabe]
# 1                                        [Aparna Ghosh]
# 2                                       [Vernae Taylor]
# 3          [Amanda Garant, Angelica Allen, Leah Garvin]
# 4                                         [Mikako Tabe]
# ...                                                 ...
# 9995                                     [Tiaré Scanda]
# 9996  [Katie McWane, Katie McWane, Michelle Concha, ...
# 9997                       [Yû Kashii, Cynthia Cheston]
# 9998                                                 []
# 9999                   [Tina De Leon, Madison Mitchell]
#
#                                     director
# 0                          [Eiichirô Hasumi]
# 1                   [Mir Asaduzzaman Ariyan]
# 2                            [Greg L. Hines]
# 3                [Tessa Olson, Jenn Carroll]
# 4                          [Eiichirô Hasumi]
# ...                                      ...
# 9995  [Felipe Nájera, Francisco Franco Alba]
# 9996                                      []
# 9997                         [Yôjirô Takita]
# 9998                           [Sven Peters]
# 9999                          [Robert Hypes]
#
# [10000 rows x 17 columns]

# %%
df.to_csv("../data/all_data_for_10000_lines.csv", index=False)
