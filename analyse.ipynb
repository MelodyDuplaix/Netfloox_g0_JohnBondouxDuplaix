# %% [markdown]
# ## Import des librairies

# %%
from sqlalchemy import create_engine
import pandas as pd
from dotenv import load_dotenv
import os

# %% [markdown]
# ## Création de la connexion

# %%
load_dotenv()  # take environment variables from .env.
database_url = os.getenv("DATABASE_URL")
engine = create_engine(database_url)

# %% [markdown]
# ## Analyse de données

# %% [markdown]
# ### Table title_basics

# %%
query = "SELECT * FROM sebastien.title_basics LIMIT 10000;"
with engine.connect() as conn, conn.begin():
    df = pd.read_sql_query(query, engine)

df.head()
# Out:
#        tconst  titletype          primarytitle         originaltitle  isadult  \
# 0   tt1521167  tvEpisode            Leerplicht            Leerplicht    False
# 1  tt15211672  tvEpisode        Episode #1.839        Episode #1.839    False
# 2  tt15211674  tvEpisode        Episode #1.840        Episode #1.840    False
# 3  tt15211676  tvEpisode  Vanderbilt vs Mizzou  Vanderbilt vs Mizzou    False
# 4  tt15211678      short                 Djinn                   Jen    False
#
#    startyear  endyear  runtimeminutes     genres  averagerating  numvotes
# 0     1982.0      NaN            21.0     Comedy            NaN       NaN
# 1        NaN      NaN             NaN  Talk-Show            NaN       NaN
# 2        NaN      NaN             NaN  Talk-Show            NaN       NaN
# 3     2020.0      NaN             NaN      Sport            NaN       NaN
# 4     1970.0      NaN             NaN      Short            NaN       NaN

# %% [markdown]
# Les films/séries qui n'ont pas suffisemment de données (trop de nan en features) seront pénalisé par le modèle par manque de données, ce qui est souhaitable puisque cela signifie qu'ils ne sont pas regardés.

# %% [markdown]
# #### Différence primary title et originaltitle

# %%
df[df["primarytitle"] == df["originaltitle"]]
# Out:
#           tconst  titletype                         primarytitle  \
# 0      tt1521167  tvEpisode                           Leerplicht
# 1     tt15211672  tvEpisode                       Episode #1.839
# 2     tt15211674  tvEpisode                       Episode #1.840
# 3     tt15211676  tvEpisode                 Vanderbilt vs Mizzou
# 5      tt1521168  tvEpisode                                Lenen
# ...          ...        ...                                  ...
# 9995  tt15230100  tvEpisode  Busty girlfriends toying each other
# 9996  tt15230102  tvEpisode                       Episode #1.389
# 9997  tt15230104  tvEpisode                       Episode #1.390
# 9998  tt15230106  tvEpisode                       Episode #1.392
# 9999  tt15230108  tvEpisode                       Episode #1.391
#
#                             originaltitle  isadult  startyear  endyear  \
# 0                              Leerplicht    False     1982.0      NaN
# 1                          Episode #1.839    False        NaN      NaN
# 2                          Episode #1.840    False        NaN      NaN
# 3                    Vanderbilt vs Mizzou    False     2020.0      NaN
# 5                                   Lenen    False     1981.0      NaN
# ...                                   ...      ...        ...      ...
# 9995  Busty girlfriends toying each other     True     2015.0      NaN
# 9996                       Episode #1.389    False        NaN      NaN
# 9997                       Episode #1.390    False        NaN      NaN
# 9998                       Episode #1.392    False        NaN      NaN
# 9999                       Episode #1.391    False        NaN      NaN
#
#       runtimeminutes     genres  averagerating  numvotes
# 0               21.0     Comedy            NaN       NaN
# 1                NaN  Talk-Show            NaN       NaN
# 2                NaN  Talk-Show            NaN       NaN
# 3                NaN      Sport            NaN       NaN
# 5               32.0     Comedy            NaN       NaN
# ...              ...        ...            ...       ...
# 9995             NaN      Adult            NaN       NaN
# 9996             NaN  Talk-Show            NaN       NaN
# 9997             NaN  Talk-Show            NaN       NaN
# 9998             NaN  Talk-Show            NaN       NaN
# 9999             NaN  Talk-Show            NaN       NaN
#
# [9886 rows x 11 columns]

# %% [markdown]
# Primary title est le titre le plus utilisé et original title et le titre original.

# %% [markdown]
# #### Analyse des genres

# %%
df["genres"].str.split(',').explode().value_counts()
# Out:
# genres
# Drama          2476
# Talk-Show      1683
# Comedy         1598
# Short          1098
# News            859
# Documentary     829
# Family          706
# Game-Show       601
# Horror          593
# Romance         464
# Action          416
# Mystery         396
# Animation       347
# Reality-TV      342
# nan             340
# Sport           329
# Adult           320
# Music           317
# Adventure       315
# Crime           216
# Fantasy         180
# History         161
# Biography       158
# Thriller        117
# Sci-Fi           71
# Musical          47
# War               9
# Western           6
# Name: count, dtype: int64

# %%
df[df["genres"] == "nan"]["titletype"].value_counts()
# Out:
# titletype
# tvEpisode       202
# tvSpecial        64
# video            31
# movie            23
# tvSeries          9
# videoGame         6
# tvMovie           4
# tvMiniSeries      1
# Name: count, dtype: int64

# %% [markdown]
# #### Analyse des notations

# %%
df[(df["averagerating"].notna()) & (df["numvotes"].isna())]
# Out:
# Empty DataFrame
# Columns: [tconst, titletype, primarytitle, originaltitle, isadult, startyear, endyear, runtimeminutes, genres, averagerating, numvotes]
# Index: []

# %% [markdown]
# Il n'y a pas de ligne ayant une note sans le nombre de vote ou l'inverse

# %%
df[df["averagerating"] == df["averagerating"].min()]
# Out:
#           tconst  titletype  \
# 8329  tt15227110  tvEpisode
#
#                                            primarytitle  \
# 8329  Caitlyn Jenner; Nancy Pelosi; Maxine Waters; R...
#
#                                           originaltitle  isadult  startyear  \
# 8329  Caitlyn Jenner; Nancy Pelosi; Maxine Waters; R...    False     2021.0
#
#       endyear  runtimeminutes genres  averagerating  numvotes
# 8329      NaN             NaN   News            1.0      97.0

# %%
query = "SELECT min(averagerating) FROM sebastien.title_basics;"
with engine.connect() as conn, conn.begin():
    df = pd.read_sql_query(query, engine)

df.head()
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df["averagerating"].describe()
# Out:
# count    1069.000000
# mean        6.955847
# std         1.447928
# min         1.000000
# 25%         6.100000
# 50%         7.100000
# 75%         8.000000
# max        10.000000
# Name: averagerating, dtype: float64

# %% [markdown]
# #### Analyse des types

# %%
df["titletype"].value_counts()
# Out:
# titletype
# tvEpisode       7605
# short           1106
# movie            509
# video            300
# tvSeries         218
# tvMovie          152
# tvSpecial         65
# tvMiniSeries      25
# videoGame         12
# tvShort            8
# Name: count, dtype: int64

# %%
df[df["titletype"] == "tvEpisode"]
# Out:
#           tconst  titletype  \
# 1      tt1787830  tvEpisode
# 26    tt17878548  tvEpisode
# 32    tt17878590  tvEpisode
# 48    tt17878746  tvEpisode
# 54    tt17878790  tvEpisode
# ...          ...        ...
# 9995   tt1794686  tvEpisode
# 9996  tt17946862  tvEpisode
# 9997   tt1794687  tvEpisode
# 9998   tt1794688  tvEpisode
# 9999   tt1794689  tvEpisode
#
#                                            primarytitle  \
# 1     Troubadours: Carole King/James Taylor & the Ri...
# 26      Top 10 Disaster Movies That Could Really Happen
# 32               The LIBBY SHOW LIVE from Christmas Con
# 48                                         Episode #1.4
# 54                                      Episode #1.9276
# ...                                                 ...
# 9995                        Episode dated 28 April 1969
# 9996                                      Episode #12.5
# 9997  Bampy Battles Bots/Truth, Revision, and the Le...
# 9998                                  The Malone Family
# 9999                     Episode dated 22 November 2010
#
#                                           originaltitle  isadult  startyear  \
# 1     Troubadours: Carole King/James Taylor & the Ri...    False     2011.0
# 26      Top 10 Disaster Movies That Could Really Happen    False     2022.0
# 32               The LIBBY SHOW LIVE from Christmas Con    False     2021.0
# 48                                         Episode #1.4    False     2022.0
# 54                                      Episode #1.9276    False     2022.0
# ...                                                 ...      ...        ...
# 9995                        Episode dated 28 April 1969    False     1969.0
# 9996                                      Episode #12.5    False     2022.0
# 9997  Bampy Battles Bots/Truth, Revision, and the Le...    False     2011.0
# 9998                                  The Malone Family    False     2010.0
# 9999                     Episode dated 22 November 2010    False     2010.0
#
#       endyear  runtimeminutes                         genres  averagerating  \
# 1         NaN           101.0  Biography,Documentary,History            8.1
# 26        NaN             NaN               Comedy,Talk-Show            NaN
# 32        NaN             NaN                      Talk-Show            NaN
# 48        NaN             NaN                          Drama            NaN
# 54        NaN             NaN            Crime,Drama,Romance            NaN
# ...       ...             ...                            ...            ...
# 9995      NaN             NaN                         Comedy            NaN
# 9996      NaN            60.0                 News,Talk-Show            NaN
# 9997      NaN            25.0     Action,Adventure,Animation            5.1
# 9998      NaN             NaN                     Reality-TV            NaN
# 9999      NaN             NaN                           News            NaN
#
#       numvotes
# 1        137.0
# 26         NaN
# 32         NaN
# 48         NaN
# 54         NaN
# ...        ...
# 9995       NaN
# 9996       NaN
# 9997      37.0
# 9998       NaN
# 9999       NaN
#
# [7605 rows x 11 columns]

# %% [markdown]
# ### Lien avec title_episode

# %%
query = f"SELECT * FROM sebastien.title_episode LIMIT 10;"
with engine.connect() as conn, conn.begin():
    df_episode = pd.read_sql_query(query, engine)

df_episode.head()
# Out:
#       tconst parenttconst  seasonnumber  episodenumber
# 0  tt0031458   tt32857063           NaN            NaN
# 1  tt0041951    tt0041038           1.0            9.0
# 2  tt0042816    tt0989125           1.0           17.0
# 3  tt0042889    tt0989125           NaN            NaN
# 4  tt0043426    tt0040051           3.0           42.0

# %%
query = f"SELECT * FROM sebastien.title_basics WHERE tconst = 'tt0048893' LIMIT 10;"
with engine.connect() as conn, conn.begin():
    df_episode = pd.read_sql_query(query, engine)

df_episode.head()
# Out:
# Empty DataFrame
# Columns: [tconst, titletype, primarytitle, originaltitle, isadult, startyear, endyear, runtimeminutes, genres, averagerating, numvotes]
# Index: []

# %%
tvEpisode = df[df["titletype"] == "tvSeries"]["tconst"].values[1]
tvEpisode
# Out:
# 'tt1787843'

# %%
query = f"SELECT * FROM sebastien.title_episode WHERE parenttconst = '{tvEpisode}' LIMIT 10;"
with engine.connect() as conn, conn.begin():
    df_episode = pd.read_sql_query(query, engine)

df_episode.head()
# Out:
# Empty DataFrame
# Columns: [tconst, parenttconst, seasonnumber, episodenumber]
# Index: []

# %%
query = "SELECT * FROM sebastien.title_basics WHERE primarytitle LIKE 'Parlement' LIMIT 10;"
with engine.connect() as conn:
    df_episode = pd.read_sql_query(query, conn)

df_episode.head()
# Out:
#       tconst titletype primarytitle originaltitle  isadult  startyear endyear  \
# 0  tt9812666  tvSeries    Parlement     Parlement    False       2020    None
#
#    runtimeminutes  genres  averagerating  numvotes
# 0              25  Comedy            7.7      1206

# %%
query = f"SELECT * FROM sebastien.title_episode WHERE parenttconst = 'tt9812666' LIMIT 10;"
with engine.connect() as conn, conn.begin():
    df_episode = pd.read_sql_query(query, engine)

df_episode.head()
# Out:
#        tconst parenttconst  seasonnumber  episodenumber
# 0  tt12136640    tt9812666             1              1
# 1  tt12136656    tt9812666             1              2
# 2  tt12136660    tt9812666             1              3
# 3  tt12136662    tt9812666             1              4
# 4  tt12136666    tt9812666             1              5

# %%
query = f"SELECT * FROM sebastien.title_basics WHERE tconst = 'tt12136666' LIMIT 10;"
with engine.connect() as conn, conn.begin():
    df_episode = pd.read_sql_query(query, engine)

df_episode.head()
# Out:
# Empty DataFrame
# Columns: [tconst, titletype, primarytitle, originaltitle, isadult, startyear, endyear, runtimeminutes, genres, averagerating, numvotes]
# Index: []

# %% [markdown]
# tvEpisode est bien une série qui peux avoir un tconst lié dans title_episode. tvSeries est bien une série qui peux avoir un parenttconst lié dans title_episode.

# %% [markdown]
# ### Table title_akas

# %%
query = f"SELECT * FROM sebastien.title_akas LIMIT 10000;"
with engine.connect() as conn, conn.begin():
    df_akas = pd.read_sql_query(query, engine)

df_akas.head()
# Out:
#    identifiant     tconst  ordering                  title region language  \
# 0         1238  tt0000284         2  At the Photographer's     US       \N
# 1         1239  tt0000284         3    Chez le photographe     FR       \N
# 2         1240  tt0000284         4            У фотографа     RU       \N
# 3         1241  tt0000285         1          Chinese Magic     \N       \N
# 4         1242  tt0000285         2          Chinese Magic     GB       \N
#
#          types attributes isoriginaltitle
# 0          dvd         \N            None
# 1  imdbDisplay         \N            None
# 2  imdbDisplay         \N            None
# 3     original         \N            None
# 4  imdbDisplay         \N            None

# %%
query = """
SELECT tb.tconst, tb.primaryTitle, ta.region
FROM sebastien.title_basics AS tb 
JOIN sebastien.title_akas AS ta 
ON tb.tconst = ta.tconst
LIMIT 200;
"""
with engine.connect() as conn, conn.begin():
    df_akas = pd.read_sql_query(query, conn)

df_akas.head()
# Out:
#        tconst    primarytitle region
# 0  tt33889296  Episode #1.220     IT
# 1  tt33889296  Episode #1.220     DE
# 2  tt33889296  Episode #1.220     JP
# 3  tt33889296  Episode #1.220     ES
# 4  tt33889297  Episode #1.221     \N

# %%
df_akas.groupby(["tconst", "primarytitle"])["region"].count()
# Out:
# tconst      primarytitle
# tt33889296  Episode #1.220                           4
# tt33889297  Episode #1.221                           8
# tt33889299  Episode #1.222                           8
# tt3388930   Episode #1.36                            8
# tt33889300  Episode #1.223                           8
# tt33889301  Denise Darcel                            1
# tt33889302  Episode #1.224                           8
# tt33889303  Episode #1.225                           8
# tt33889304  Episode #1.226                           8
# tt33889305  The Rats of Venice                       2
# tt33889306  Episode #1.227                           8
# tt33889307  Episode #1.228                           8
# tt33889308  Episode #1.229                           8
# tt33889309  Episode #1.230                           8
# tt33889310  Episode #1.231                           8
# tt33889311  Episode #1.232                           8
# tt33889312  Episode #1.233                           8
# tt33889313  Episode #1.234                           8
# tt33889314  Episode #1.235                           8
# tt33889315  The Eldo-Drakonisian War                 1
# tt33889316  Episode #1.236                           8
# tt33889317  Episode #1.237                           8
# tt33889318  Episode #1.238                           8
# tt33889319  Episode #1.239                           8
# tt3388932   Episode #1.35                            8
# tt33889320  DE MUYBRIDGE A LUMIERE                   2
# tt33889321  TikTok Star takes BBC by the Roadside    2
# tt33889323  Épisode 1, Épisode 2                     1
# tt33889324  Episode #1.240                           8
# tt33889325  O Bairro do Humor                        2
# tt33889326  Episode #1.241                           8
# tt33889327  Episode #1.242                           1
# Name: region, dtype: int64

# %% [markdown]
# On peux utiliser le nombre de régions par film dans les features, mais en utilisant pandas et non sql pour calculer le nombre de régions par film.

# %%
import numpy as np


df_akas["region"] = df_akas["region"].replace("\\N", np.nan)
df_akas.dropna(subset=["region"], inplace=True)
df_akas.groupby(["tconst", "primarytitle"])['region'].agg(list)
# Out:
# tconst      primarytitle
# tt33889296  Episode #1.220                                       [IT, DE, JP, ES]
# tt33889297  Episode #1.221                           [PT, IN, FR, IT, DE, JP, ES]
# tt33889299  Episode #1.222                           [PT, IN, FR, IT, DE, JP, ES]
# tt3388930   Episode #1.36                            [PT, IN, FR, IT, DE, JP, ES]
# tt33889300  Episode #1.223                           [PT, IN, FR, IT, DE, JP, ES]
# tt33889302  Episode #1.224                           [PT, IN, FR, IT, DE, JP, ES]
# tt33889303  Episode #1.225                           [PT, IN, FR, IT, DE, JP, ES]
# tt33889304  Episode #1.226                           [PT, IN, FR, IT, DE, JP, ES]
# tt33889305  The Rats of Venice                                               [GB]
# tt33889306  Episode #1.227                           [PT, IN, FR, IT, DE, JP, ES]
# tt33889307  Episode #1.228                           [PT, IN, FR, IT, DE, JP, ES]
# tt33889308  Episode #1.229                           [PT, IN, FR, IT, DE, JP, ES]
# tt33889309  Episode #1.230                           [PT, IN, FR, IT, DE, JP, ES]
# tt33889310  Episode #1.231                           [PT, IN, FR, IT, DE, JP, ES]
# tt33889311  Episode #1.232                           [PT, IN, FR, IT, DE, JP, ES]
# tt33889312  Episode #1.233                           [PT, IN, FR, IT, DE, JP, ES]
# tt33889313  Episode #1.234                           [PT, IN, FR, IT, DE, JP, ES]
# tt33889314  Episode #1.235                           [PT, IN, FR, IT, DE, JP, ES]
# tt33889316  Episode #1.236                           [PT, IN, FR, IT, DE, JP, ES]
# tt33889317  Episode #1.237                           [PT, IN, FR, IT, DE, JP, ES]
# tt33889318  Episode #1.238                           [PT, IN, FR, IT, DE, JP, ES]
# tt33889319  Episode #1.239                           [PT, IN, FR, IT, DE, JP, ES]
# tt3388932   Episode #1.35                            [PT, IN, FR, IT, DE, JP, ES]
# tt33889320  DE MUYBRIDGE A LUMIERE                                           [BR]
# tt33889321  TikTok Star takes BBC by the Roadside                            [GB]
# tt33889324  Episode #1.240                           [PT, IN, FR, IT, DE, JP, ES]
# tt33889325  O Bairro do Humor                                                [PT]
# tt33889326  Episode #1.241                           [PT, IN, FR, IT, DE, JP, ES]
# Name: region, dtype: object

# %% [markdown]
# On peux aussi utiliser la liste des régions par films comme features.

# %%
df_akas["region"].unique()
# Out:
# array(['IT', 'DE', 'JP', 'ES', 'PT', 'IN', 'FR', 'GB', 'BR'], dtype=object)

# %% [markdown]
# ### Analyse de title_principals

# %%
query = f"SELECT * FROM sebastien.title_principals LIMIT 10000;"
with engine.connect() as conn, conn.begin():
    df_principals = pd.read_sql_query(query, engine)

df_principals.head()
# Out:
#    identifiant      tconst  ordering      nconst  category       job  \
# 0     33562099  tt15312350         3   nm6004811   actress        \N
# 1     33562100  tt15312350         4   nm8941959   actress        \N
# 2     33562101  tt15312350         5  nm10176104     actor        \N
# 3     33562102  tt15312350         6   nm4861794  director        \N
# 4     33562103  tt15312350         7  nm14167000    writer  dialogue
#
#                          characters
# 0   ["Head Constable Pushpa Singh"]
# 1             ["Constable Santosh"]
# 2  ["Constable Cheetah Chaturvedi"]
# 3                                \N
# 4                                \N

# %%
query = f"SELECT * FROM sebastien.title_principals as tp JOIN sebastien.name_basics as nb ON nb.nconst = tp.nconst LIMIT 10000;"
with engine.connect() as conn, conn.begin():
    df_principals = pd.read_sql_query(query, engine)

df_principals.head(25)
# Out:
#     identifiant      tconst  ordering     nconst          category       job  \
# 0      33599337  tt15322122        26  nm0892064  casting_director        \N
# 1      33599338  tt15322124         1  nm1930205              self        \N
# 2      33599339  tt15322126         1  nm4050901              self        \N
# 3      33599340  tt15322128         1  nm1478339             actor        \N
# 4      33599341  tt15322128         2  nm0535434           actress        \N
# 5      33599342  tt15322128         3  nm0029239           actress        \N
# 6      33599343  tt15322128         4  nm0505447             actor        \N
# 7      33599344  tt15322128         5  nm0888863             actor        \N
# 8      33599345  tt15322128         6  nm5365532           actress        \N
# 9      33599346  tt15322128         7  nm0737332             actor        \N
# 10     33599347  tt15322128         8  nm3730877           actress        \N
# 11     33599348  tt15322128         9  nm0375454             actor        \N
# 12     33599349  tt15322128        10  nm0885622             actor        \N
# 13     33599350   tt1532213         1  nm2729927              self        \N
# 14     33599351   tt1532213         2  nm3252122          director        \N
# 15     33599352   tt1532213         3  nm0621392          producer  producer
# 16     33599353   tt1532213         4  nm3252122            editor        \N
# 17     33599354  tt15322130         1  nm0305374             actor        \N
# 18     33599355  tt15322130         2  nm0695395           actress        \N
# 19     33599356  tt15322130         3  nm0605301             actor        \N
# 20     33599357  tt15322130         4  nm0022299           actress        \N
# 21     33599358  tt15322130         5  nm0499202             actor        \N
# 22     33599359  tt15322130         6  nm0872966             actor        \N
# 23     33599360  tt15322130         7  nm0013793             actor        \N
# 24     33599361  tt15322130         8  nm1007928             actor        \N
#
#                        characters     nconst          primaryname  birthyear  \
# 0                              \N  nm0892064        René Veilleux        NaN
# 1            ["Self - Presenter"]  nm1930205         Jules Hudson     1970.0
# 2            ["Self - Presenter"]  nm4050901          Steve Brown        NaN
# 3             ["Niko Schuurmans"]  nm1478339              Jo Hens        NaN
# 4       ["Mieke Van den Bossche"]  nm0535434        Caroline Maes     1976.0
# 5   ["Veronique Van den Bossche"]  nm0029239       Sandrine André     1973.0
# 6       ["Peter Van den Bossche"]  nm0505447         Gunther Levi     1976.0
# 7               ["Benny Coppens"]  nm0888863   Roel Vanderstukken     1976.0
# 8            ["Stefanie Coppens"]  nm5365532     Jasmijn Van Hoof        NaN
# 9                ["Lars De Wulf"]  nm0737332         Kürt Rogiers     1971.0
# 10             ["Amélie De Wulf"]  nm3730877     Erika Van Tielen        NaN
# 11            ["Patrick Pauwels"]  nm0375454         Ludo Hellinx     1955.0
# 12             ["Alfons Coppens"]  nm0885622      Jaak Van Assche     1940.0
# 13                ["Self - Host"]  nm2729927       David Jeremiah     1941.0
# 14                             \N  nm3252122         Troy Dausend        NaN
# 15                             \N  nm0621392      Joseph Narducci        NaN
# 16                             \N  nm3252122         Troy Dausend        NaN
# 17                             \N  nm0305374       Patrick Garcia     1981.0
# 18                             \N  nm0695395        Camille Prats     1985.0
# 19                             \N  nm0605301         Stefano Mori        NaN
# 20                             \N  nm0022299     Ani Pearl Alonzo        NaN
# 21                             \N  nm0499202  Karl Angelo Legaspi        NaN
# 22                             \N  nm0872966        Koko Trinidad        NaN
# 23                             \N  nm0013793       Marvin Agustin     1979.0
# 24                             \N  nm1007928      Mat Ranillo III     1956.0
#
#     deathyear                                  primaryprofession  \
# 0         NaN  casting_director,casting_department,miscellaneous
# 1         NaN                              actor,archive_footage
# 2         NaN                                               None
# 3         NaN                                              actor
# 4         NaN                            actress,archive_footage
# 5         NaN                            actress,archive_footage
# 6         NaN                              actor,archive_footage
# 7         NaN                              actor,archive_footage
# 8         NaN                          actress,script_department
# 9         NaN                       actor,writer,archive_footage
# 10        NaN                            actress,archive_footage
# 11        NaN                              actor,archive_footage
# 12        NaN                    actor,director,casting_director
# 13        NaN                    writer,producer,archive_footage
# 14        NaN                    director,editor,cinematographer
# 15        NaN                  producer,actor,assistant_director
# 16        NaN                    director,editor,cinematographer
# 17        NaN                                              actor
# 18        NaN                                 actress,soundtrack
# 19        NaN                                              actor
# 20        NaN                                            actress
# 21        NaN                                              actor
# 22        NaN                                              actor
# 23        NaN                       actor,director,miscellaneous
# 24        NaN                                   actor,soundtrack
#
#                                 knownfortitles
# 0   tt12681586,tt13090810,tt13352178,tt3485722
# 1    tt0165064,tt0445887,tt13051960,tt16972146
# 2    tt30485397,tt3770700,tt6377480,tt15317252
# 3      tt0162076,tt9756106,tt0217205,tt2981372
# 4      tt0243733,tt0219394,tt0217221,tt0287269
# 5      tt0830854,tt0162076,tt1648168,tt3641514
# 6     tt0227974,tt0162076,tt8736020,tt32749395
# 7      tt1688211,tt1298297,tt0217205,tt3543082
# 8     tt5203748,tt2981372,tt13850522,tt4047050
# 9      tt0382365,tt4733540,tt1467394,tt2276275
# 10     tt1538545,tt6438030,tt2256612,tt1678044
# 11     tt0227909,tt0217205,tt1442563,tt0149453
# 12     tt0149412,tt1815013,tt0149475,tt0454024
# 13    tt23321406,tt1343861,tt6928532,tt0278229
# 14              tt1343861,tt23321406,tt5171594
# 15    tt0107614,tt23321406,tt1343861,tt1493239
# 16              tt1343861,tt23321406,tt5171594
# 17     tt0216563,tt0219155,tt0218821,tt0219295
# 18     tt0219155,tt0281168,tt0380738,tt0327472
# 19     tt0292098,tt0380738,tt0123251,tt0352080
# 20     tt0347354,tt0281168,tt0409456,tt0399989
# 21     tt0335140,tt0312933,tt0127064,tt0123251
# 22     tt0264778,tt0219155,tt0362112,tt0155844
# 23     tt0368323,tt0479693,tt0216753,tt2104022
# 24     tt0359487,tt0336820,tt0313549,tt0474912

# %%
df_principals["category"].value_counts()
# Out:
# category
# actor                  2014
# actress                1686
# writer                 1452
# self                   1191
# director               1161
# producer                775
# editor                  676
# cinematographer         424
# composer                336
# production_designer     138
# casting_director         81
# archive_footage          66
# Name: count, dtype: int64

# %% [markdown]
# La catégorie peux être une feature, en gardant les acteur / actrices / self (personne qui se représente elle même type célébrité ou emission de télé ou autobiographie) / producteur

# %%
df_principals["knownfortitles2"] = df_principals["knownfortitles"].apply(lambda x: len(x.split(",")) if x else 0)
df_principals
# Out:
#       identifiant      tconst  ordering      nconst          category  \
# 0        33599337  tt15322122        26   nm0892064  casting_director
# 1        33599338  tt15322124         1   nm1930205              self
# 2        33599339  tt15322126         1   nm4050901              self
# 3        33599340  tt15322128         1   nm1478339             actor
# 4        33599341  tt15322128         2   nm0535434           actress
# ...           ...         ...       ...         ...               ...
# 9995     33609332  tt15324358        15  nm11011614   cinematographer
# 9996     33609333  tt15324358        16   nm9948754   cinematographer
# 9997     33609334  tt15324358        17   nm7477080            editor
# 9998     33609335  tt15324358        18  nm12270003            editor
# 9999     33609336  tt15324360         1   nm6181328           actress
#
#                   job                 characters      nconst    primaryname  \
# 0                  \N                         \N   nm0892064  René Veilleux
# 1                  \N       ["Self - Presenter"]   nm1930205   Jules Hudson
# 2                  \N       ["Self - Presenter"]   nm4050901    Steve Brown
# 3                  \N        ["Niko Schuurmans"]   nm1478339        Jo Hens
# 4                  \N  ["Mieke Van den Bossche"]   nm0535434  Caroline Maes
# ...               ...                        ...         ...            ...
# 9995  cinematographer                         \N  nm11011614  Manish V Soni
# 9996               \N                         \N   nm9948754     Rahul Soni
# 9997               \N                         \N   nm7477080  Pankaj Katpal
# 9998               \N                         \N  nm12270003   Rahul Mathur
# 9999               \N  ["S.H.O. Haseena Mallik"]   nm6181328    Gulki Joshi
#
#       birthyear  deathyear                                  primaryprofession  \
# 0           NaN        NaN  casting_director,casting_department,miscellaneous
# 1        1970.0        NaN                              actor,archive_footage
# 2           NaN        NaN                                               None
# 3           NaN        NaN                                              actor
# 4        1976.0        NaN                            actress,archive_footage
# ...         ...        ...                                                ...
# 9995        NaN        NaN                                    cinematographer
# 9996        NaN        NaN                                    cinematographer
# 9997        NaN        NaN                                             editor
# 9998        NaN        NaN                               editor,miscellaneous
# 9999     1990.0        NaN                                            actress
#
#                                   knownfortitles  knownfortitles2
# 0     tt12681586,tt13090810,tt13352178,tt3485722                4
# 1      tt0165064,tt0445887,tt13051960,tt16972146                4
# 2      tt30485397,tt3770700,tt6377480,tt15317252                4
# 3        tt0162076,tt9756106,tt0217205,tt2981372                4
# 4        tt0243733,tt0219394,tt0217221,tt0287269                4
# ...                                          ...              ...
# 9995  tt15464420,tt11867650,tt9760930,tt15458502                4
# 9996  tt27727527,tt32536908,tt5929848,tt11867650                4
# 9997  tt15234990,tt4886424,tt11867650,tt33047479                4
# 9998  tt14071150,tt11867650,tt7209352,tt12651104                4
# 9999   tt11867650,tt3418990,tt15523028,tt9135686                4
#
# [10000 rows x 14 columns]

# %%
df_principals.groupby("category")["knownfortitles2"].mean()
# Out:
# category
# actor                  3.214835
# actress                3.576488
# archive_footage        3.285714
# casting_director       3.650000
# cinematographer        3.454777
# composer               3.167920
# director               2.673729
# editor                 3.032644
# producer               3.047847
# production_designer    3.863636
# self                   3.035011
# writer                 2.673077
# Name: knownfortitles2, dtype: float64

# %% [markdown]
# On est pas sûre de la pertinence de cette features, on ne sait pas.

# %% [markdown]
# ### Analyse de title_crew

# %%
query = f"SELECT * FROM sebastien.title_crew LIMIT 10000;"
with engine.connect() as conn, conn.begin():
    df_crew = pd.read_sql_query(query, engine)

df_crew.head()
# Out:
#       tconst  directors              writers
# 0  tt0008746  nm0454535  nm0166777,nm0795082
# 1  tt0008747         \N                   \N
# 2  tt0008748  nm0911959            nm0518844
# 3  tt0008749  nm0204677                   \N
# 4  tt0008750  nm0912817            nm0551361

# %%
df_crew.head(35)
# Out:
#        tconst            directors                                  writers
# 0   tt0008746            nm0454535                      nm0166777,nm0795082
# 1   tt0008747                   \N                                       \N
# 2   tt0008748            nm0911959                                nm0518844
# 3   tt0008749            nm0204677                                       \N
# 4   tt0008750            nm0912817                                nm0551361
# 5   tt0008752                   \N                                nm0907778
# 6   tt0008753            nm0912817                      nm0167424,nm0398464
# 7   tt0008754            nm0154352                      nm0547966,nm0791014
# 8   tt0008755            nm0916113                                       \N
# 9   tt0008756            nm0588056                                nm0370271
# 10  tt0008757            nm0818423                                nm0649932
# 11  tt0008758            nm1720536                                nm1720536
# 12  tt0008759            nm0523932                      nm0523932,nm0778218
# 13  tt0008760            nm0601190                                nm0408932
# 14  tt0008761            nm0932134                                       \N
# 15  tt0008762            nm0361882                                       \N
# 16  tt0008763            nm0515979                      nm0262961,nm0515979
# 17  tt0008764            nm0869665            nm0357902,nm0707674,nm0926417
# 18  tt0008765            nm0048478                      nm0048478,nm0517786
# 19  tt0008766            nm0247358                      nm0150432,nm0885808
# 20  tt0008767            nm0078340                                nm0337612
# 21  tt0008768            nm0285643                      nm0522971,nm0662701
# 22  tt0008769            nm0160280                                nm1242439
# 23  tt0008770            nm0237710                      nm0237710,nm0533102
# 24  tt0008771  nm0237693,nm0237713  nm0107838,nm0237693,nm0237713,nm0610467
# 25  tt0008772            nm0631438                                nm0631438
# 26  tt0008773            nm0049995                      nm0682784,nm0927032
# 27  tt0008774            nm0933045                                nm0307234
# 28  tt0008775            nm0256221            nm0139356,nm0002616,nm0256221
# 29  tt0008776                   \N                                       \N
# 30  tt0008777            nm0208657                      nm0533954,nm0662701
# 31  tt0008778            nm0166836                                       \N
# 32  tt0008779            nm0577654                      nm0390818,nm0857710
# 33  tt0008780                   \N                                       \N
# 34  tt0008781            nm0247358                      nm0612348,nm0892045

# %% [markdown]
# Si on a le temps, ca peux être une features d'amélioration future.
